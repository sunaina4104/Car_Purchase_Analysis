# %%
# import the needed libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load the data
data=pd.read_csv(r"C:\Users\user\Downloads\Car_Purchasing_Data (1).csv")

# %%
# review thre data
data
# Out:
#        Customer Name                                    Customer e-mail  \
# 0      Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1      Harlan Barnes                                eu.dolor@diam.co.uk
# 2    Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3    Jade Cunningham                            malesuada@dignissim.com
# 4       Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
# ..               ...                                                ...
# 495           Walter                                ligula@Cumsociis.ca
# 496            Vanna                 Cum.sociis.natoque@Sedmolestie.edu
# 497            Pearl                      penatibus.et@massanonante.com
# 498             Nell                  Quisque.varius@arcuVivamussit.net
# 499            Marla                          Camaron.marla@hotmail.com
#
#     Country  Gender  Age  Annual Salary  Credit Card Debt    Net Worth  \
# ...

# %%
# Check data type 
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
# Check data shape (Rows,Columns)     (Records,Fields)
data.shape
# Out:
# (500, 9)

# %%
# check data to find the null values and data types of the columns in the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Customer Name        500 non-null    object
#  1   Customer e-mail      500 non-null    object
#  2   Country              500 non-null    object
#  3   Gender               500 non-null    int64
#  4   Age                  500 non-null    int64
#  5   Annual Salary        500 non-null    float64
#  6   Credit Card Debt     500 non-null    float64
#  7   Net Worth            500 non-null    float64
#  8   Car Purchase Amount  500 non-null    float64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 35.3+ KB

# %%
# To check the sum of null values in each column 
data.isnull().sum()
# Out:
# Customer Name          0
# Customer e-mail        0
# Country                0
# Gender                 0
# Age                    0
# Annual Salary          0
# Credit Card Debt       0
# Net Worth              0
# Car Purchase Amount    0
# dtype: int64

# %%
# To vcheck the sum of duplicate values in each column 
data.duplicated().sum()
# Out:
# 0

# %%
# To check the top 5 rows of data set ....if you want to check more than 5 rows you can write in parenthesis...otherwise it will show only top 5 by default
data.head()
# Out:
#      Customer Name                                    Customer e-mail Country  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu     USA
# 1    Harlan Barnes                                eu.dolor@diam.co.uk     USA
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...     USA
# 3  Jade Cunningham                            malesuada@dignissim.com     USA
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net     USA
#
#    Gender  Age  Annual Salary  Credit Card Debt    Net Worth  \
# 0       0   42    62812.09301      11609.380910  238961.2505
# 1       0   41    66646.89292       9572.957136  530973.9078
# 2       1   43    53798.55112      11160.355060  638467.1773
# 3       1   58    79370.03798      14426.164850  548599.0524
# 4       1   57    59729.15130       5358.712177  560304.0671
#
#    Car Purchase Amount
# 0          35321.45877
# 1          45115.52566
# 2          42925.70921
# 3          67422.36313
# ...

# %%
# To check the statistics of the data
data.describe()
# Out:
#            Gender         Age  Annual Salary  Credit Card Debt  \
# count  500.000000  500.000000     500.000000        500.000000
# mean     0.506000   46.224000   62127.239608       9607.645049
# std      0.500465    7.990339   11703.378228       3489.187973
# min      0.000000   20.000000   20000.000000        100.000000
# 25%      0.000000   41.000000   54391.977195       7397.515792
# 50%      1.000000   46.000000   62915.497035       9655.035568
# 75%      1.000000   52.000000   70117.862005      11798.867487
# max      1.000000   70.000000  100000.000000      20000.000000
#
#             Net Worth  Car Purchase Amount
# count      500.000000           500.000000
# mean    431475.713625         44209.799218
# std     173536.756340         10773.178744
# min      20000.000000          9000.000000
# 25%     299824.195900         37629.896040
# 50%     426750.120650         43997.783390
# 75%     557324.478725         51254.709517
# max    1000000.000000         80000.000000

# %%
# to check the count of customers and to check the repeated customers 
data['Customer Name'].value_counts()
# Out:
# Customer Name
# Seth                    2
# Walter                  2
# Martina Avila           1
# Sexton, Shaeleigh H.    1
# Holloway, Brennan Q.    1
#                        ..
# Holmes Irwin            1
# Hector Price            1
# Sebastian Marks         1
# Marvin Garner           1
# Marla                   1
# Name: count, Length: 498, dtype: int64

# %%
# to check the count of email
data["Customer e-mail"].value_counts()
# Out:
# Customer e-mail
# cubilia.Curae.Phasellus@quisaccumsanconvallis.edu    1
# mi.eleifend.egestas@cursuset.net                     1
# ut@Etiamvestibulum.ca                                1
# nunc.sed.pede@Quisqueporttitor.net                   1
# Cras.eu@vitaevelitegestas.net                        1
#                                                     ..
# Nunc.sed.orci@Namligulaelit.net                      1
# Aliquam.nisl@semegetmassa.co.uk                      1
# et.eros@feugiatmetussit.net                          1
# in@sed.org                                           1
# Camaron.marla@hotmail.com                            1
# Name: count, Length: 500, dtype: int64

# %%
# to check the country column 
data["Country"].value_counts()
# Out:
# Country
# USA    500
# Name: count, dtype: int64

# %%
data.drop(columns="Country",inplace = True)

# %%
data.shape
# Out:
# (500, 8)

# %%
data["Age"].value_counts()
# Out:
# Age
# 43    34
# 51    29
# 42    26
# 47    25
# 48    25
# 40    24
# 44    23
# 45    23
# 53    20
# 46    19
# 50    19
# 41    19
# 57    17
# 55    16
# 52    15
# 49    14
# 37    14
# 39    14
# 56    11
# 35    10
# 54    10
# 38    10
# 33    10
# 32     9
# 36     9
# 58     7
# 34     6
# 59     6
# 63     6
# 62     5
# 61     5
# 60     5
# 30     3
# 29     2
# 70     2
# 20     1
# 31     1
# 27     1
# 22     1
# 65     1
# 64     1
# 28     1
# 25     1
# Name: count, dtype: int64

# %%
# Convert all the columns into numeric 
df_numeric = data.apply(pd.to_numeric, errors='coerce')

# %%
# Select only numeric columns out of it 
df_numeric_only = df_numeric.select_dtypes(include=['int64', 'float64'])

# %%
# Calculate the correlation of that columns 
correlation_matrix = df_numeric_only.corr()
correlation_matrix
# Out:
#                      Customer Name  Customer e-mail    Gender       Age  \
# Customer Name                  NaN              NaN       NaN       NaN
# Customer e-mail                NaN              NaN       NaN       NaN
# Gender                         NaN              NaN  1.000000 -0.066488
# Age                            NaN              NaN -0.066488  1.000000
# Annual Salary                  NaN              NaN -0.036499  0.000361
# Credit Card Debt               NaN              NaN  0.024193  0.031748
# Net Worth                      NaN              NaN -0.008395  0.021794
# Car Purchase Amount            NaN              NaN -0.066408  0.633273
#
#                      Annual Salary  Credit Card Debt  Net Worth  \
# Customer Name                  NaN               NaN        NaN
# Customer e-mail                NaN               NaN        NaN
# Gender                   -0.036499          0.024193  -0.008395
# ...

# %%
# To calculate the average annual salary 
average_annual_salary = data["Annual Salary"].mean()
print(average_annual_salary)
# Out:
# 62127.23960756

# %%
# Calculated the average credit card debt 
average_credit_card_debt = data["Credit Card Debt"].mean()
print(average_credit_card_debt)
# Out:
# 9607.645048629198

# %%
# Calculated Average net worth
average_net_worth = data["Net Worth"].mean()
print(average_net_worth)
# Out:
# 431475.71362506005

# %%
# Calculated average Car purchase amount
average_car_purchase_amount = data["Car Purchase Amount"].mean()
print(average_car_purchase_amount)
# Out:
# 44209.79921842

# %%
# Sorted the data alphabatically (A-Z)
data.sort_values(by='Customer Name')
# Out:
#           Customer Name                    Customer e-mail  Gender  Age  \
# 82         Abel Stanton        eu.lacus.Quisque@congue.edu       1   40
# 290  Abigail X. Lindsey                      dui@nondui.ca       0   63
# 204      Abra D. Golden                      odio@Duis.com       0   54
# 77         Adria Mathis     Aliquam.rutrum.lorem@Donec.net       1   57
# 124        Adrian Brock    Cras.lorem@nonvestibulumnec.net       0   54
# ..                  ...                                ...     ...  ...
# 239       Zane I. Boone                    blandit@Cum.edu       1   45
# 21        Zelenia Byers            auctor.non@sapien.co.uk       0   48
# 237     Zelenia L. Lowe  Nunc.mauris.elit@Curabiturvel.edu       0   51
# 295      Zenia H. Patel                     dis@tortor.com       1   40
# 472            Zephania                   montes@sedsem.ca       1   39
#
#      Annual Salary  Credit Card Debt    Net Worth  Car Purchase Amount
# ...

# %%
# Average car purchase according to age 
age_purchase = data.groupby('Age')['Car Purchase Amount'].mean()

plt.plot(age_purchase.index, age_purchase.values, color = 'purple')
plt.xlabel("Age")
plt.ylabel("Average Purchase Amount")
plt.title("Age vs Average Car Purchase Amount")
plt.show()

# %%
# Males VS Females Average car purchase Amount
gender_wise_car_purchase = data.groupby('Gender')['Car Purchase Amount'].mean()

gender_wise_car_purchase.plot(kind='bar' , color =['pink', 'navy'] )

plt.xlabel("Gender (0 = Female, 1 = Male)")
plt.ylabel("Average Car Purchase Amount")
plt.title("Males VS Females Average car purchase Amount")
plt.show()

# %%
# Distribution frequency of annual salary
plt.hist(data['Annual Salary'], bins=10, color = 'lightgreen')
plt.xlabel("Annual Salary")
plt.ylabel("Frequency")
plt.title("Distribution of Annual Salary")
plt.show()

# %%
# check the car purchase amount according to annual salary
plt.scatter(data['Annual Salary'], data['Car Purchase Amount'], color = 'red')
plt.xlabel("Annual Salary")
plt.ylabel("Car Purchase Amount")
plt.title("Salary vs Car Purchase Amount")
plt.show()

# %%
# Distribution of salary according to gender
sns.boxplot(x='Gender', y='Annual Salary', data=data, color = 'yellow')
plt.title("Salary Distribution by Gender")
plt.show()

# %%
corr = data[['Age', 'Annual Salary', 'Net Worth', 'Car Purchase Amount']].corr()

sns.heatmap(corr, annot=True)
plt.title("Correlation Heatmap")
plt.show()

# %%
# ENCODING CUSTOMER NAME
from sklearn.preprocessing import LabelEncoder
# CREATE A LABELENCODER OBJECT
label_encoder=LabelEncoder()
# FIT AND TRANSFORM THE "FUEL COLUMN"
data["Customer Name encoded"] = label_encoder.fit_transform(data["Customer Name"])
print(data[["Customer Name","Customer Name encoded"]])
# Out:
#        Customer Name  Customer Name encoded
# 0      Martina Avila                    288
# 1      Harlan Barnes                    168
# 2    Naomi Rodriquez                    311
# 3    Jade Cunningham                    204
# 4       Cedric Leach                     70
# ..               ...                    ...
# 495           Walter                    475
# 496            Vanna                    466
# 497            Pearl                    352
# 498             Nell                    315
# 499            Marla                    284
#
# [500 rows x 2 columns]

# %%
# ENCODING CUSTOMER email
from sklearn.preprocessing import LabelEncoder
# CREATE A LABELENCODER OBJECT
label_encoder=LabelEncoder()
# FIT AND TRANSFORM THE "FUEL COLUMN"
data["Customer e-mail encoded"] = label_encoder.fit_transform(data["Customer e-mail"])
print(data[["Customer e-mail","Customer e-mail encoded"]])
# Out:
#                                        Customer e-mail  \
# 0    cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1                                  eu.dolor@diam.co.uk
# 2    vulputate.mauris.sagittis@ametconsectetueradip...
# 3                              malesuada@dignissim.com
# 4       felis.ullamcorper.viverra@egetmollislectus.net
# ..                                                 ...
# 495                                ligula@Cumsociis.ca
# 496                 Cum.sociis.natoque@Sedmolestie.edu
# 497                      penatibus.et@massanonante.com
# 498                  Quisque.varius@arcuVivamussit.net
# 499                          Camaron.marla@hotmail.com
#
#      Customer e-mail encoded
# 0                        139
# 1                        224
# 2                        498
# 3                        307
# 4                        241
# ..                       ...
# 495                      289
# 496                       21
# 497                      381
# ...

# %%
data.head()
# Out:
#      Customer Name                                    Customer e-mail  Gender  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu       0
# 1    Harlan Barnes                                eu.dolor@diam.co.uk       0
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...       1
# 3  Jade Cunningham                            malesuada@dignissim.com       1
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net       1
#
#    Age  Annual Salary  Credit Card Debt    Net Worth  Car Purchase Amount  \
# 0   42    62812.09301      11609.380910  238961.2505          35321.45877
# 1   41    66646.89292       9572.957136  530973.9078          45115.52566
# 2   43    53798.55112      11160.355060  638467.1773          42925.70921
# 3   58    79370.03798      14426.164850  548599.0524          67422.36313
# 4   57    59729.15130       5358.712177  560304.0671          55915.46248
#
#    Customer Name encoded  Customer e-mail encoded
# ...

# %%
sns.pairplot(data)
plt.title("Car Purchasing Data Pairplot",fontsize=10,color = 'yellow')
# Out:
# Text(0.5, 1.0, 'Car Purchasing Data Pairplot')

# %%
data.drop(columns=["Customer Name", "Customer e-mail"], inplace=True)

# %%
data.corr()
# Out:
#                            Gender       Age  Annual Salary  Credit Card Debt  \
# Gender                   1.000000 -0.066488      -0.036499          0.024193
# Age                     -0.066488  1.000000       0.000361          0.031748
# Annual Salary           -0.036499  0.000361       1.000000          0.049599
# Credit Card Debt         0.024193  0.031748       0.049599          1.000000
# Net Worth               -0.008395  0.021794       0.014767         -0.049378
# Car Purchase Amount     -0.066408  0.633273       0.617862          0.028882
# Customer Name encoded   -0.021926  0.016523       0.038859          0.028952
# Customer e-mail encoded  0.073458 -0.041863       0.010627          0.019145
#
#                          Net Worth  Car Purchase Amount  \
# Gender                   -0.008395            -0.066408
# Age                       0.021794             0.633273
# Annual Salary             0.014767             0.617862
# ...

# %%
corr = data[['Age','Gender', 'Annual Salary', 'Net Worth', 'Car Purchase Amount','Customer Name encoded','Customer e-mail encoded']].corr()

sns.heatmap(corr, annot=True)
plt.title("Correlation Heatmap")
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

# %%
#Independent and dependent features
x=data[["Age","Annual Salary","Net Worth","Gender","Customer Name encoded","Customer e-mail encoded",]]
y=data["Car Purchase Amount"]

# %%
#Train test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
print(x_train)
# Out:
#      Age  Annual Salary     Net Worth  Gender  Customer Name encoded  \
# 227   39    63675.93263   74257.82785       0                     67
# 417   42    64412.43101  355175.36770       0                    199
# 203   57    50241.48985  607395.01830       0                    248
# 126   59    66905.47644  651215.64350       0                     72
# 329   44    45504.74866  374777.69290       1                    250
# ..   ...            ...           ...     ...                    ...
# 106   42    51075.46118  450402.29320       0                    438
# 270   35    33422.99683  211168.62930       0                    464
# 348   45    63561.04525  608019.63080       0                    478
# 435   58    41409.29390  421318.97640       1                     45
# 102   30    68289.18229  404457.30990       1                     49
#
#      Customer e-mail encoded
# 227                      300
# 417                      386
# 203                      480
# ...

# %%
print(x_test)
# Out:
#      Age  Annual Salary     Net Worth  Gender  Customer Name encoded  \
# 361   36    74420.10254  551344.33650       0                     32
# 73    48    59139.21080  473845.85460       1                    293
# 374   57    67752.38329  657178.41350       1                    266
# 155   50    55381.53225   20000.00000       0                     98
# 104   48    63975.06090  891439.87610       0                    487
# ..   ...            ...           ...     ...                    ...
# 220   59    77662.11090  331460.47270       1                    274
# 176   45    62043.16623  357639.03340       1                     10
# 320   45    79781.90126  427287.62770       0                    484
# 153   34    55576.84068  475126.12520       0                    113
# 231   49    77435.46545   48620.32123       0                    131
#
#      Customer e-mail encoded
# 361                      133
# 73                       238
# 374                      378
# ...

# %%
print(y_train)
# Out:
# 227    29002.05665
# 417    39439.45349
# 203    51683.60859
# 126    64391.68906
# 329    31526.04931
#           ...
# 106    34803.82395
# 270    12536.93842
# 348    49348.88394
# 435    42139.64528
# 102    33640.73697
# Name: Car Purchase Amount, Length: 375, dtype: float64

# %%
print(y_test)
# Out:
# 361    46082.80993
# 73     45058.89690
# 374    63079.84329
# 155    31837.22537
# 104    60461.24268
#           ...
# 220    61118.46947
# 176    41265.52929
# 320    52983.89411
# 153    31300.54347
# 231    44432.71747
# Name: Car Purchase Amount, Length: 125, dtype: float64

# %%
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)

# %%
#MODEL
from sklearn.linear_model import LinearRegression
regression=LinearRegression()

# %%
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=regression.predict(x_test)

# %%
intercept=regression.intercept_
coeff=regression.coef_
print("intercept: ",intercept)
print("coefficients:",coeff)
# Out:
# intercept:  43869.88850224
# coefficients: [6708.46389993 6680.74515679 5079.84924006   19.90834877    9.56190054
#    11.21199336]

# %%
y_predict
# Out:
# array([45969.46639797, 45260.68016017, 62966.68428016, 31643.34485874,
#        60045.8040296 , 63016.05915267, 52181.47148584, 54513.84946652,
#        52398.05814327, 48300.79808563, 37965.32134801, 56145.1290642 ,
#        44593.74532085, 39324.39769324, 40206.20442889, 55252.90630441,
#        48530.81560208, 17256.19213604, 60918.14167233, 50039.58960197,
#        41584.85473091, 52646.65741169, 51782.28967467, 38442.26754124,
#        41067.12299165, 38680.60927542, 64201.46972015, 47974.16322561,
#        23059.62306678, 52473.50433823, 54949.81825693, 46110.80659427,
#        41463.48726346, 57332.05950948, 42846.17627769, 39657.4098392 ,
#        61922.88571494, 30719.6317484 , 41856.40457464, 39949.56600076,
#        57304.96606001, 61059.91175685, 47061.51401904, 36395.87079077,
#        53040.53143544, 44806.11218622, 35452.23135952, 42153.85789762,
#        52102.59051469, 47649.19731534, 41975.09574332, 32750.58967993,
# ...

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,mean_absolute_percentage_error
mae=mean_absolute_error(y_test,y_predict)
mse=mean_squared_error(y_test,y_predict)
mape=mean_absolute_percentage_error(y_test,y_predict)
rmse=np.sqrt(mse)
print("mae=",mae)
print("mse=",mse)
print("mape=",mape)
print("rmse=",rmse)
# Out:
# mae= 215.10880700433685
# mse= 62065.04454697423
# mape= 0.005066323913952219
# rmse= 249.1285703145551

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_predict)
print(score)
#display adjusted R-squared
print(1 - (1-score)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1))
# Out:
# 0.9994158693590651
# 0.9993861678010515

# %%
## cross validation
from sklearn.model_selection import cross_val_score
validation_score=cross_val_score(regression,x_train,y_train,scoring='neg_mean_squared_error',
                                cv=3)

# %%
np.mean(validation_score)
# Out:
# -59618.849454469746

# %%
## prediction
y_pred=regression.predict(x_test)
print(y_pred)
# Out:
# [45969.46639797 45260.68016017 62966.68428016 31643.34485874
#  60045.8040296  63016.05915267 52181.47148584 54513.84946652
#  52398.05814327 48300.79808563 37965.32134801 56145.1290642
#  44593.74532085 39324.39769324 40206.20442889 55252.90630441
#  48530.81560208 17256.19213604 60918.14167233 50039.58960197
#  41584.85473091 52646.65741169 51782.28967467 38442.26754124
#  41067.12299165 38680.60927542 64201.46972015 47974.16322561
#  23059.62306678 52473.50433823 54949.81825693 46110.80659427
#  41463.48726346 57332.05950948 42846.17627769 39657.4098392
#  61922.88571494 30719.6317484  41856.40457464 39949.56600076
#  57304.96606001 61059.91175685 47061.51401904 36395.87079077
#  53040.53143544 44806.11218622 35452.23135952 42153.85789762
#  52102.59051469 47649.19731534 41975.09574332 32750.58967993
#  38260.9244851  41539.59043671 44801.80359564 47956.32500177
#  60593.22749841 44769.67915061 44699.21548188 38398.57389194
# ...

# %%
## Performance Metrics
from sklearn.metrics import mean_absolute_error,mean_squared_error
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
rmse=np.sqrt(mse)
print(mse)
print(mae)
print(rmse)
# Out:
# 62065.04454697423
# 215.10880700433685
# 249.1285703145551

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)
print(score)
#display adjusted R-squared
print(1 - (1-score)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1))
# Out:
# 0.9994158693590651
# 0.9993861678010515
